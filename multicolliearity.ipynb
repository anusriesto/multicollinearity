# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\LENOVO\Desktop\ANN CLASS\Multicollinearity-master\data\Advertising.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper
# 0           1  230.1   37.8       69.2
# 1           2   44.5   39.3       45.1
# 2           3   17.2   45.9       69.3
# 3           4  151.5   41.3       58.5
# 4           5  180.8   10.8       58.4

# %%
import statsmodels.api as sm
import statsmodels.api as add_constant

# %%
#now we are adding an intercept
x=sm.add_constant(x)
x
# Out:
#      const  Unnamed: 0     TV  radio  newspaper
# 0      1.0           1  230.1   37.8       69.2
# 1      1.0           2   44.5   39.3       45.1
# 2      1.0           3   17.2   45.9       69.3
# 3      1.0           4  151.5   41.3       58.5
# 4      1.0           5  180.8   10.8       58.4
# 5      1.0           6    8.7   48.9       75.0
# 6      1.0           7   57.5   32.8       23.5
# 7      1.0           8  120.2   19.6       11.6
# 8      1.0           9    8.6    2.1        1.0
# 9      1.0          10  199.8    2.6       21.2
# 10     1.0          11   66.1    5.8       24.2
# 11     1.0          12  214.7   24.0        4.0
# 12     1.0          13   23.8   35.1       65.9
# 13     1.0          14   97.5    7.6        7.2
# 14     1.0          15  204.1   32.9       46.0
# 15     1.0          16  195.4   47.7       52.9
# 16     1.0          17   67.8   36.6      114.0
# 17     1.0          18  281.4   39.6       55.8
# 18     1.0          19   69.2   20.5       18.3
# ...

# %%
##now we will check for corealation
model=sm.OLS(y,x).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                     425.7
# Date:                Mon, 14 Dec 2020   Prob (F-statistic):           3.94e-95
# Time:                        08:15:01   Log-Likelihood:                -386.14
# No. Observations:                 200   AIC:                             782.3
# Df Residuals:                     195   BIC:                             798.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.0052      0.394      7.623      0.000       2.228       3.783
# ...

# %%
#above oe is confusing so we will see it as simple as that
x.iloc[:,1:].corr()
# Out:
#             Unnamed: 0        TV     radio  newspaper
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944
# TV            0.017715  1.000000  0.054809   0.056648
# radio        -0.110680  0.054809  1.000000   0.354104
# newspaper    -0.154944  0.056648  0.354104   1.000000

# %%
#kuch jayada connection nai mila 
#there is no corellation between the datas so it is safe to say that our 
#computation power will be more

# %%
dt=pd.read_csv(r'C:\Users\LENOVO\Desktop\ANN CLASS\Multicollinearity-master\data\Salary_Data.csv')
dt.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
x1=dt.iloc[:,:-1]
y1=dt.iloc[:,-1]
x1=sm.add_constant(x1)
x1
# Out:
#     const  YearsExperience   Age
# 0     1.0              1.1  21.0
# 1     1.0              1.3  21.5
# 2     1.0              1.5  21.7
# 3     1.0              2.0  22.0
# 4     1.0              2.2  22.2
# 5     1.0              2.9  23.0
# 6     1.0              3.0  23.0
# 7     1.0              3.2  23.3
# 8     1.0              3.2  23.3
# 9     1.0              3.7  23.6
# 10    1.0              3.9  23.9
# 11    1.0              4.0  24.0
# 12    1.0              4.0  24.0
# 13    1.0              4.1  24.0
# 14    1.0              4.5  25.0
# 15    1.0              4.9  25.0
# 16    1.0              5.1  26.0
# 17    1.0              5.3  27.0
# 18    1.0              5.9  28.0
# 19    1.0              6.0  29.0
# 20    1.0              6.8  30.0
# 21    1.0              7.1  30.0
# 22    1.0              7.9  31.0
# 23    1.0              8.2  32.0
# 24    1.0              8.7  33.0
# 25    1.0              9.0  34.0
# 26    1.0              9.5  35.0
# ...

# %%
x1.iloc[:,1:].corr()
# Out:
#                  YearsExperience       Age
# YearsExperience         1.000000  0.987258
# Age                     0.987258  1.000000

# %%
#bahut jyada dependency ha data meh so we can drop any column
